# %% [markdown]
#  Created on Thu Dec 20 13:23:15 2018
#
#  @author: espenfb

# %%
import os
import sys
from pathlib import Path

filepath = os.path.abspath('')
sys.path.append(str(Path(filepath).parent / "src"))

import detInvModel as dim
import pandas as pd
import savedRes as sr

time_data = {
'start_date': pd.Timestamp(year = 2015, month = 1, day = 1),
'end_date': pd.Timestamp(year = 2016, month = 1, day = 1),
'ref_date': pd.Timestamp(year = 2015, month = 1, day = 1)}
dirs = {
'data_dir' : "data\\",
'ctrl_data_file' : 'ctrl_data.csv',
'res_dir' : 'results\\'}

# %%
obj = dim.deterministicModel(time_data, dirs)
# Out:
# 0 load Series/bus_loads_2050.csv
# data\Series/bus_loads_2050.csv
# 1 solar Series/solar_profiles_adj.csv
# data\Series/solar_profiles_adj.csv
# 2 wind Series/pot_wind_profile.csv
# data\Series/pot_wind_profile.csv
# 3 inst_wind Series/inst_wind_profile.csv
# data\Series/inst_wind_profile.csv
# 4 offshore_wind Series/pot_wind_profile.csv
# data\Series/pot_wind_profile.csv

# %%
obj.buildModel()
# Out:
# Building deterministic investment model...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\espenb\Models\HEIM\demo\run_detInvModel.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/espenb/Models/HEIM/demo/run_detInvModel.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> obj.buildModel()
#
# File c:\Users\espenb\Models\HEIM\src\detInvModel.py:59, in deterministicModel.buildModel(self)
#      56 self.detModel = dif.buildDetModel(mutables=self.mutables)
#      58 # Create concrete instance
# ---> 59 self.detDataInstance = did.detData(self)
#      60 print('Creating LP problem instance...')
#      61 self.instance = self.detModel.create_instance(
#      62                         data=self.detDataInstance,
#      63                         name="Deterministic operation model",
#      64                         namespace='detData')
#
# File c:\Users\espenb\Models\HEIM\src\detInvData.py:20, in detData(obj)
#      17 h2_pf = 'HN'
#      18 market_pf = "MN"
# ---> 20 dual_buses = node_data[node_data.Type == "Dual"]
#      22 di['EL_NODES'] = {None: [el_pf + '%.2d' %
#      23                          i for i in dual_buses.Bus.tolist()]}
#      24 di['H2_NODES'] = {None: [h2_pf + '%.2d' %
#      25                          i for i in dual_buses.Bus.tolist()]}
#
# File c:\Users\espenb\Miniconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Type'

# %%
obj.solve()

# %%
obj.processResults()

obj.saveRes(dirs['res_dir'])

res = sr.savedRes(dirs['res_dir'], data = obj.data)
